# %%
import random
from random import randint
from IPython.html import widgets 
from IPython.display import display
from ipythonblocks import BlockGrid
from IPython.html.widgets import interact, interactive

# %%
#def nhood(GridSize):
#    grid = BlockGrid(GridSize,GridSize,fill=(0,0,0))
#    grid.show()
#    return grid

# %%
#nhood(8)

# %%
#def fillWithPop(red,blue):
#    maxWorld = GridSize*GridSize
#    for i in grid:
#        for j in grid:

# %%
#For my plan to work, set the empty/white spots into a dictionary.  Each white spot corresponds to a number... so like, grid[2,4] is white... = 2
#Then, in my function, we'll set the satisfied spot equal to that previously white spot (randomly chosen).  At the same time, we take out that white spot from the dictionary so that the next one can't take the same spot
#def movingToEmptySpot():
#    for i in grid:
#        for j in grid:
#            if grid[i,j].green == 0:

# %%
#Making the grid with colors or seomthing
#wanted_water_cell = 10
#wanted_oil_cell = 10



#def grid_check():
#    x = randint(0,grid.width - 1)
#    y = randint(0,grid.height - 1)
#    while grid[x,y] != (0,0,0):
#        x = randint(0,grid.width - 1)
#        y = randint(0,grid.height - 1)
#    
#    return x,y


#def fill_cells(wanted_water_cell, wanted_oil_cell):
#    grid=BlockGrid(wanted_wanter_cell, wanted_oi_cell),fill=(0,0,0)
#    for i in grid:
#        for j in grid:
#            grid[i,j] = 
    
#    water_cell = 0
#    oil_cell = 0
#    empty_cell = 0
        
#    while wanted_water_cell > water_cell:
        
#        grid_check()
        
#        grid[x,y]=(0,0,255)
        #Take out of Dictionary
#        water_cell += 1
#        print x,y

        
#    while wanted_oil_cell > oil_cell:
        
#        grid_check()
        
#        grid[x,y]=(0,0,255)
        #Take out of Dictionary
#        oil_cell += 1
#        print x,y

# %%
# How this part should look once we're using the sliders

grid = BlockGrid(5,5)           #Creates grid

if (RedPop + BluePop)> 100:
    print "Choose values that don't exceed 100 %"
else:
    for i in range(grid.height):
        for j in range(grid.width):
            rand_int1 = random.randint(1,100)
            if rand_int1 <= RedPop:
                grid[i,j] = (0, 0, 255)
            elif rand_int1 <= (RedPop + BluePop):
                grid[i,j] = (255, 0, 0)
            elif rand_int1 > (RedPop + BluePop):
                grid[i,j] = (0, 0, 0)
        
            if grid[i,j] == (0, 0, 255):
                grid[i,j] = blue
            elif grid[i,j] == (255, 0, 0):
                grid[i,j] = red
            elif grid[i,j] == (0, 0, 0):
                grid[i,j] = green
            cell1 = grid[i,j]
grid.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-811b80a2930f> in <module>()
#       3 grid = BlockGrid(5,5)           #Creates grid
#       4
# ----> 5 if (RedPop + BluePop)> 100:
#       6     print "Choose values that don't exceed 100 %"
#       7 else:
#
# NameError: name 'RedPop' is not defined

# %%
def equal_color(a,b):
    if (a.red,a.green,a.blue)==(b.red,b.green,b.blue):
        return True 
    else:
        return False

# %%
def equal_black(a):
    if (a.red == 0) and (a.green == 0) and (a.blue == 0):
        return True
    else:
        return False

# %%
#working current cell
def satisfaction(grid,i,j):
    if grid[i,j]!=(0,0,0):
        GridSize = grid.width
        sat = 0
            
        if i == 0 or j == 0 or i == GridSize-1 or j == GridSize-1:   #Edges
                
            MaxNeighbors = 5
            #Corners            
            if i == 0 and j == 0:
                MaxNeighbors = 3


                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1 
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors -= 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors -= 1
                
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction    

            elif i == 0 and j == GridSize-1:

                MaxNeighbors = 3

                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i+1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors -= 1
                
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction


            elif (i==GridSize-1 and j ==0):

                MaxNeighbors = 3

                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors -= 1
                
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction

            elif (i == GridSize  and j ==GridSize-1):

                MaxNeighbors = 3

                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors -= 1

                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction

  #Edge Pieces...NOT CORNERS

            elif i == 0 and j != 0 and j!=GridSize-1 :
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors -= 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i+1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors -= 1

                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction

            elif j == 0 and i!=0 and i!=GridSize-1:
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors -= 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors -= 1
                
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction

            elif i == GridSize and j !=0 and j!=GridSize-1:
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1, j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1, j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors -= 1
                
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction

            elif j == GridSize and i!=0 and i != GridSize-1:
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1, j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1, j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors -= 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors -= 1
                if equal_color(grid[i+1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors -= 1
                
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction

            
        #All the pieces inside...non-edge    
        else:
            MaxNeighbors = 8
            if equal_color(grid[i+1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j],):
                MaxNeighbors -= 1
            if equal_color(grid[i+1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j+1]):
                MaxNeighbors -= 1
            if equal_color(grid[i,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j+1]):
                MaxNeighbors -= 1
            if equal_color(grid[i-1, j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1, j-1]):
                MaxNeighbors -= 1
            if equal_color(grid[i-1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j]):
                MaxNeighbors -= 1
            if equal_color(grid[i,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j-1]):
                MaxNeighbors -= 1
            if equal_color(grid[i-1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j+1]):
                MaxNeighbors -= 1
            if equal_color(grid[i+1,j-1],grid[i,j]): 
                sat = sat + 1
            elif equal_black(grid[i+1,j-1]):
                MaxNeighbors -= 1
            
            if MaxNeighbors == 0:
                satisfaction = 0
                return satisfaction
            else:
                satisfaction = float(sat) / float(MaxNeighbors)
                return satisfaction

    else:
        return None

# %%
def find_movers(grid,threshold):
    movers = []
    nulls = []
    for i in range(grid.width):
        for j in range(grid.height):
            if equal_black(grid[i,j]):
                nulls.append((i,j))
            else:
                if satisfaction(grid,i,j) < threshold:
                    movers.append((i,j))
        #for d in movers:
            #print grid[d].rgb                #Checker
    
    
    
    
    
    for i in range(len(movers)):
            p = random.randint(0,len(nulls))
            
            print nulls[p],movers[i]
            
            grid[nulls[p]].rgb = grid[movers[i]].rgb #Change color of the empty space randomly chosen to the color of the current movers (unsatisfied) spot
            grid[movers[i]].rgb = (0,0,0)   # This should actually change the grid
            nulls.remove(nulls[p])
    grid.show()

# %%
grid = BlockGrid(5,5)
for i in range(grid.height):
    for j in range(grid.width):
        rand_int1 = random.randint(1,3)
        if rand_int1 == 1:
            grid[i,j] = (0, 0, 255)
        elif rand_int1 == 2:
            grid[i,j] = (255, 0, 0)
        elif rand_int1 == 3:
            grid[i,j] = (0, 0, 0)
        
        if grid[i,j] == (0, 0, 255):
            grid[i,j] = blue
        elif grid[i,j] == (255, 0, 0):
            grid[i,j] = red
        elif grid[i,j] == (0, 0, 0):
            grid[i,j] = black
        
grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks75a7b918-981e-4c33-9a8a-e8b23387d87f td {border: 1px solid white;}</style><table id="blocks75a7b918-981e-4c33-9a8a-e8b23387d87f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 2]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0
# ...

# %%
find_movers(grid,0.5)
# Out:
# (1, 0) (0, 0)
# (4, 3) (0, 4)
# (0, 3) (1, 1)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-222a9980c554> in <module>()
# ----> 1 find_movers(grid,0.5)
#
# <ipython-input-30-aec7338c367d> in find_movers(grid, threshold)
#      19             p = random.randint(0,len(nulls))
#      20
# ---> 21             print nulls[p],movers[i]
#      22
#      23             grid[nulls[p]].rgb = grid[movers[i]].rgb #Change color of the empty space randomly chosen to the color of the current movers (unsatisfied) spot
#
# IndexError: list index out of range

# %%
#def move(movers,nulls)
#Current main function to move the stuff
for i in range(len(movers)):
    p = random.randint(0,len(nulls))
    grid[nulls[p]].rgb = grid[movers[i]].rgb #Change color of the empty space randomly chosen to the color of the current movers (unsatisfied) spot
    grid[movers[i]].rgb = (0,0,0)   # This should actually change the grid
    nulls.remove(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-82fc917f6734> in <module>()
#       1 #def move(movers,nulls)
# ----> 2 for i in range(len(movers)):
#       3     p = random.randint(0,len(nulls))
#       4     grid[nulls[p]].rgb = grid[movers[i]].rgb #Change color of the empty space randomly chosen to the color of the current movers (unsatisfied) spot
#       5     grid[movers[i]].rgb = (0,0,0)   # This should actually change the grid
#
# NameError: name 'movers' is not defined

# %%
#def move_agents(grid,threshold):
#    for i in range(len(movers)):
#       
#       for null in nulls:
            original_color = grid[movers[0]].rgb     #move the mover to a null and replace null with mover
            grid[null] = grid[movers[0]]
            grid[movers[0]] = white
            if satisfaction(grid, null[1],null[0]) < threshold: 
                grid[null] = white              #if mover is not satisfied move it back to where it was before
                grid[movers[0]] = original_color
                if nulls[len(nulls) - 1] == null:    # if mover has no place to go then keep it where it is
                    movers.remove(movers[0])
                    print null
            else:
                nulls.remove(null)          
                nulls.append(movers[0])
                movers.remove(movers[0])
                break

# %%
#def move(movers,nulls)
for i in range(len(movers)):
    p = random.randit(0,len(nulls))
    grid[nulls[p]].rgb = grid[movers[i]].rgb #Change color of the empty space randomly chosen to the color of the current movers (unsatisfied) spot
    grid[movers[i]].rgb = (0,0,0)   # This should actually change the grid
    nulls.remove(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-4ee289791868> in <module>()
#       1 #def move(movers,nulls)
# ----> 2 for i in range(len(movers)):
#       3     p = random.randit(0,len(nulls))
#       4     grid[nulls[p]].rgb = grid[movers[i]].rgb #Change color of the empty space randomly chosen to the color of the current movers (unsatisfied) spot
#       5     grid[movers[i]].rgb = (0,0,0)   # This should actually change the grid
#
# NameError: name 'movers' is not defined

# %%
#def satisfy_that_sh(t)
#for i in range(grid.height):
#   for j in range(grid.width): 
#        same_cells = 0
#        diff_cells = 0
#        t = same_cells/diff_cells #satisfaction rate
#         
#            if t >= 0.3
#                pass
#            else:
#                #Try to make it so it goes to the nearest empty cell, 
#                #not just the first
#                for k in range(grid.height):
#                    for l in range(grid.width): 
#                        if grid[k,l] == (35, 35, 35):
#                            grid[k,l] = cell2
#                            if cell1 == (0, 100, 210):
#                                cell2 = (0, 100, 210)
#                                cell1 = (35, 35, 35)
#                            if cell1 == (255, 200, 70):
#                                cell2 = (255, 200, 70)
#                                cell1 = (35, 35, 35)
#                    
#Get down that satisfaction

# %% [markdown]
# # fun with sliders

# %%
#importing for this stuff is done at the top

# %%
#def sampleMean(N=10000,xmin=1.7,xmax=12.4):
#v2 = interact(sampleMean,N=(1000,100000,100),xmin=(0.,15.,0.001),xmax=(0.,15.,0.001))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-177-acde17fa2996> in <module>()
# ----> 1 v2 = interact(sampleMean,N=(1000,100000,100),xmin=(0.,15.,0.001),xmax=(0.,15.,0.001))
#
# NameError: name 'sampleMean' is not defined

# %%
L = interact(Schelling, Threshold=(0,1,.05), RedPop = (0,100,5), BluePop = (0,100,5) , POPULATION = (1,100,5))

# %% [markdown]
# # Final Big Function

# %%
def Schelling(Threshold,RedPop,BluePop,POPULATION,Iterations):
    # How this part should look once we're using the sliders

    grid = BlockGrid(5,5)           #Creates grid

    if (RedPop + BluePop)> 100:
        print "Choose values that don't exceed 100 %"
    else:
        for i in range(grid.height):
            for j in range(grid.width):
                rand_int1 = random.randint(1,100)
                if rand_int1 <= BluePop:
                    grid[i,j] = (0, 0, 255)
                elif rand_int1 <= (RedPop + BluePop):
                    grid[i,j] = (255, 0, 0)
                elif rand_int1 > (RedPop + BluePop):
                    grid[i,j] = (0, 0, 0)
        
                if grid[i,j] == (0, 0, 255):
                    grid[i,j] = blue
                elif grid[i,j] == (255, 0, 0):
                    grid[i,j] = red
                elif grid[i,j] == (0, 0, 0):
                    grid[i,j] = green
                cell1 = grid[i,j]
    grid.show()
    while Iterations > 0:
        find_movers(grid,Threshold)
        Iterations = Iterations - 1

# %%
Schelling(0.4,60,20,500,2)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksad57e659-c9c6-4ae1-bad5-2bf656e4b15b td {border: 1px solid white;}</style><table id="blocksad57e659-c9c6-4ae1-bad5-2bf656e4b15b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 
# ...
